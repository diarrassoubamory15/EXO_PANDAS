# %%
#vous aurez besoin des bubliothèque numpy, pandas et le module pyplot de la bubliothèque matplolib
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
cheminOs=os.chdir(r"D:\+projet_pandas")

# %%
#Chargez le fichier "heart" de données dans un objet appelé "data"
data = pd.read_table('heart.txt')
data
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin       100        234     A       A       156    non
# 1     41   feminin       130        204     A       C       172    non
# 2     58  masculin       150        270     A       C       111    oui
# 3     53  masculin       140        203     B       C       155    oui
# 4     41  masculin       130        214     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin       140        268     A       C       160    non
# 266   62  masculin       130        231     A       A       146    non
# 267   64  masculin       110        211     A       C       144    oui
# 268   63   feminin       150        407     A       C       154    non
# 269   35   feminin       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# 1            14    1        A   absence
# 2             8    1        A  presence
# 3            31    3        A  presence
# 4            20    2        A   absence
# ..          ...  ...      ...       ...
# 265          36    3        C  presence
# 266          18    2        D   absence
# 267          18    2        A   absence
# 268          40    2        D  presence
# 269          14    1        A   absence
#
# [270 rows x 12 columns]

# %%
#Copiez data dans un autre object appelé df
df = data.copy()
df
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin       100        234     A       A       156    non
# 1     41   feminin       130        204     A       C       172    non
# 2     58  masculin       150        270     A       C       111    oui
# 3     53  masculin       140        203     B       C       155    oui
# 4     41  masculin       130        214     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin       140        268     A       C       160    non
# 266   62  masculin       130        231     A       A       146    non
# 267   64  masculin       110        211     A       C       144    oui
# 268   63   feminin       150        407     A       C       154    non
# 269   35   feminin       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# 1            14    1        A   absence
# 2             8    1        A  presence
# 3            31    3        A  presence
# 4            20    2        A   absence
# ..          ...  ...      ...       ...
# 265          36    3        C  presence
# 266          18    2        D   absence
# 267          18    2        A   absence
# 268          40    2        D  presence
# 269          14    1        A   absence
#
# [270 rows x 12 columns]

# %%
#les 10 prmiers lignes de votre objet df
df.head(10)
# Out:
#    age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0   58  masculin       100        234     A       A       156    non
# 1   41   feminin       130        204     A       C       172    non
# 2   58  masculin       150        270     A       C       111    oui
# 3   53  masculin       140        203     B       C       155    oui
# 4   41  masculin       130        214     A       C       168    non
# 5   65   feminin       155        269     A       A       148    non
# 6   51  masculin       110        175     A       A       123    non
# 7   45   feminin       112        160     A       A       138    non
# 8   55  masculin       130        262     A       A       155    non
# 9   58   feminin       136        319     B       C       152    non
#
#    depression  pic vaisseau     coeur
# 0           1    1        B  presence
# 1          14    1        A   absence
# 2           8    1        A  presence
# 3          31    3        A  presence
# 4          20    2        A   absence
# 5           8    1        A   absence
# 6           6    1        A   absence
# 7           0    2        A   absence
# 8           0    1        A   absence
# 9           0    1        C  presence

# %%
#nombre lignes et de colonnes de l'objet df
nb_lignes = df.shape
print("nombre lignes et de colonnes de l'objet df est ",nb_lignes )
# Out:
# nombre lignes et de colonnes de l'objet df est  (270, 12)

# %%
#liste des colonnes de l'objet df
lister_c = df.columns
lister_c
# Out:
# Index(['age', 'sexe', 'pression', 'cholester', 'sucre', 'electro', 'taux_max',
#        'angine', 'depression', 'pic', 'vaisseau', 'coeur'],
#       dtype='object')

# %%
#les statistiques descriptives de l'objet df
stat_descrip = df.describe()
stat_descrip
# Out:
#               age    pression   cholester    taux_max  depression         pic
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333  131.344444  249.659259  149.677778   10.500000    1.585185
# std      9.109067   17.861608   51.686237   23.165717   11.452098    0.614390
# min     29.000000   94.000000  126.000000   71.000000    0.000000    1.000000
# 25%     48.000000  120.000000  213.000000  133.000000    0.000000    1.000000
# 50%     55.000000  130.000000  245.000000  153.500000    8.000000    2.000000
# 75%     61.000000  140.000000  280.000000  166.000000   16.000000    2.000000
# max     77.000000  200.000000  564.000000  202.000000   62.000000    3.000000

# %%
#les 4 premieres colonnes de la varible age de l'objet df en utilisant la technique d'indexing
df.iloc[:,:4]
# Out:
#      age      sexe  pression  cholester
# 0     58  masculin       100        234
# 1     41   feminin       130        204
# 2     58  masculin       150        270
# 3     53  masculin       140        203
# 4     41  masculin       130        214
# ..   ...       ...       ...        ...
# 265   62   feminin       140        268
# 266   62  masculin       130        231
# 267   64  masculin       110        211
# 268   63   feminin       150        407
# 269   35   feminin       138        183
#
# [270 rows x 4 columns]

# %%
#les 10 premiere lignes des variables age, sexe et pression en utilisant la technique du slicing
df.loc[:9, ['age', 'sexe', 'pression']]
# Out:
#    age      sexe  pression
# 0   58  masculin       100
# 1   41   feminin       130
# 2   58  masculin       150
# 3   53  masculin       140
# 4   41  masculin       130
# 5   65   feminin       155
# 6   51  masculin       110
# 7   45   feminin       112
# 8   55  masculin       130
# 9   58   feminin       136

# %%
#vérifier si une personne a plus de 50 ans
df['age']>50
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 265     True
# 266     True
# 267     True
# 268     True
# 269    False
# Name: age, Length: 270, dtype: bool

# %%
#afficher les femmes qui ont plus de 50 ans
femmes = df[(df['sexe']=='feminin') & (df['age']>50) ]
femmes
# Out:
#      age     sexe  pression  cholester sucre electro  taux_max angine  \
# 5     65  feminin       155        269     A       A       148    non
# 9     58  feminin       136        319     B       C       152    non
# 10    52  feminin       136        196     A       C       169    non
# 13    58  feminin       100        248     A       C       122    non
# 16    67  feminin       106        223     A       A       142    non
# ..   ...      ...       ...        ...   ...     ...       ...    ...
# 258   60  feminin       150        240     A       A       171    non
# 261   53  feminin       130        264     A       C       143    non
# 264   54  feminin       160        201     A       A       163    non
# 265   62  feminin       140        268     A       C       160    non
# 268   63  feminin       150        407     A       C       154    non
#
#      depression  pic vaisseau     coeur
# 5             8    1        A   absence
# 9             0    1        C  presence
# 10            1    2        A   absence
# 13           10    2        A   absence
# 16            3    1        C   absence
# ..          ...  ...      ...       ...
# 258           9    1        A   absence
# 261           4    2        A   absence
# 264           0    1        B   absence
# 265          36    3        C  presence
# 268          40    2        D  presence
#
# [61 rows x 12 columns]

# %%
#afficher les femmes plus de 50 ans qui ont une maladie cardiaque
maladie_card = df[(df['sexe']=='feminin') & (df['age']>50) & (df['coeur']=='presence') ]
maladie_card
# Out:
#      age     sexe  pression  cholester sucre electro  taux_max angine  \
# 9     58  feminin       136        319     B       C       152    non
# 38    60  feminin       158        305     A       C       161    non
# 74    60  feminin       150        258     A       C       157    non
# 76    56  feminin       200        288     B       C       133    oui
# 87    65  feminin       150        225     A       C       114    non
# 104   62  feminin       150        244     A       A       154    oui
# 118   63  feminin       108        269     A       A       169    oui
# 120   59  feminin       174        249     A       A       143    oui
# 135   62  feminin       138        294     B       A       106    non
# 141   55  feminin       180        327     A       B       117    oui
# 146   56  feminin       134        409     A       C       150    oui
# 150   61  feminin       130        330     A       C       169    non
# 153   61  feminin       145        307     A       C       146    oui
# 175   66  feminin       178        228     B       A       165    oui
# 186   51  feminin       130        305     A       A       142    oui
# 203   62  feminin       160        164     A       C       145    non
# 250   62  feminin       130        263     A       A        97    non
# 265   62  feminin       140        268     A       C       160    non
# 268   63  feminin       150        407     A       C       154    non
#
#      depression  pic vaisseau     coeur
# 9             0    1        C  presence
# 38            0    1        A  presence
# 74           26    2        C  presence
# 76           40    3        C  presence
# 87           10    2        D  presence
# 104          14    2        A  presence
# 118          18    2        C  presence
# 120           0    2        A  presence
# 135          19    2        D  presence
# 141          34    2        A  presence
# 146          19    2        C  presence
# 150           0    1        A  presence
# 153          10    2        A  presence
# 175          10    2        C  presence
# 186          12    2        A  presence
# 203          62    3        D  presence
# 250          12    2        B  presence
# 265          36    3        C  presence
# 268          40    2        D  presence

# %%
#verifier s'il y a des donnees manquantes
df.isnull()
# Out:
#        age   sexe  pression  cholester  sucre  electro  taux_max  angine  \
# 0    False  False     False      False  False    False     False   False
# 1    False  False     False      False  False    False     False   False
# 2    False  False     False      False  False    False     False   False
# 3    False  False     False      False  False    False     False   False
# 4    False  False     False      False  False    False     False   False
# ..     ...    ...       ...        ...    ...      ...       ...     ...
# 265  False  False     False      False  False    False     False   False
# 266  False  False     False      False  False    False     False   False
# 267  False  False     False      False  False    False     False   False
# 268  False  False     False      False  False    False     False   False
# 269  False  False     False      False  False    False     False   False
#
#      depression    pic  vaisseau  coeur
# 0         False  False     False  False
# 1         False  False     False  False
# 2         False  False     False  False
# 3         False  False     False  False
# 4         False  False     False  False
# ..          ...    ...       ...    ...
# 265       False  False     False  False
# 266       False  False     False  False
# 267       False  False     False  False
# 268       False  False     False  False
# 269       False  False     False  False
#
# [270 rows x 12 columns]

# %%
#Deuxième verification pour être sure
df.isnull().sum()
# Out:
# age           0
# sexe          0
# pression      0
# cholester     0
# sucre         0
# electro       0
# taux_max      0
# angine        0
# depression    0
# pic           0
# vaisseau      0
# coeur         0
# dtype: int64

# %%
#suppression les lignes ou il y a des donnees maquantes
suppression = df.dropna(axis=0)
suppression
#Ce qui veut dire qu'il n'y a pas de ligne à supprimer
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin       100        234     A       A       156    non
# 1     41   feminin       130        204     A       C       172    non
# 2     58  masculin       150        270     A       C       111    oui
# 3     53  masculin       140        203     B       C       155    oui
# 4     41  masculin       130        214     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin       140        268     A       C       160    non
# 266   62  masculin       130        231     A       A       146    non
# 267   64  masculin       110        211     A       C       144    oui
# 268   63   feminin       150        407     A       C       154    non
# 269   35   feminin       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# 1            14    1        A   absence
# 2             8    1        A  presence
# 3            31    3        A  presence
# 4            20    2        A   absence
# ..          ...  ...      ...       ...
# 265          36    3        C  presence
# 266          18    2        D   absence
# 267          18    2        A   absence
# 268          40    2        D  presence
# 269          14    1        A   absence
#
# [270 rows x 12 columns]

# %%
#Recodage de sexe (0 pour masculin et 1 pour féminin)
df["sexe"]= df["sexe"].replace(["masculin","feminin"],[0,1])
df
# Out:
#      age  sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58     0       100        234     A       A       156    non
# 1     41     1       130        204     A       C       172    non
# 2     58     0       150        270     A       C       111    oui
# 3     53     0       140        203     B       C       155    oui
# 4     41     0       130        214     A       C       168    non
# ..   ...   ...       ...        ...   ...     ...       ...    ...
# 265   62     1       140        268     A       C       160    non
# 266   62     0       130        231     A       A       146    non
# 267   64     0       110        211     A       C       144    oui
# 268   63     1       150        407     A       C       154    non
# 269   35     1       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# 1            14    1        A   absence
# 2             8    1        A  presence
# 3            31    3        A  presence
# 4            20    2        A   absence
# ..          ...  ...      ...       ...
# 265          36    3        C  presence
# 266          18    2        D   absence
# 267          18    2        A   absence
# 268          40    2        D  presence
# 269          14    1        A   absence
#
# [270 rows x 12 columns]

# %%
#supprimer les variable depression, vaisseau et pic du dataframe
supprimer_v = df.drop(['depression','vaisseau','pic'], axis=1)
supprimer_v
# Out:
#      age  sexe  pression  cholester sucre electro  taux_max angine     coeur
# 0     58     0       100        234     A       A       156    non  presence
# 1     41     1       130        204     A       C       172    non   absence
# 2     58     0       150        270     A       C       111    oui  presence
# 3     53     0       140        203     B       C       155    oui  presence
# 4     41     0       130        214     A       C       168    non   absence
# ..   ...   ...       ...        ...   ...     ...       ...    ...       ...
# 265   62     1       140        268     A       C       160    non  presence
# 266   62     0       130        231     A       A       146    non   absence
# 267   64     0       110        211     A       C       144    oui   absence
# 268   63     1       150        407     A       C       154    non  presence
# 269   35     1       138        183     A       A       182    non   absence
#
# [270 rows x 9 columns]

# %%
#Representation graphique de la variable coeur
plt.figure()
df['coeur'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='coeur'>

# %%
data.dtypes
# Out:
# age            int64
# sexe          object
# pression       int64
# cholester      int64
# sucre         object
# electro       object
# taux_max       int64
# angine        object
# depression     int64
# pic            int64
# vaisseau      object
# coeur         object
# dtype: object

# %%
data.select_dtypes("object").columns
qual = data.select_dtypes("object").columns
qual
# Out:
# Index(['sexe', 'sucre', 'electro', 'angine', 'vaisseau', 'coeur'], dtype='object')

# %%
#Representation graphique de toutes les variables qualitatives
plt.figure(figsize=[17,10])

plt.gcf().subplots_adjust(hspace = 0.5)

i=1
for vq in qual:
    plt.subplot(3,3,i)
    x= data[vq].value_counts()
    x.plot(kind='pie')
    plt.title(vq)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-a181ca509323> in <module>
#       8     plt.subplot(3,3,i)
#       9     x= data[vq].value_counts()
# ---> 10     x.plot(kind='pie')
#      11     plt.title(vq)
#      12     i+=1
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     264         self._add_table()
#     265         self._make_legend()
# --> 266         self._adorn_subplots()
#     267
#     268         for ax in self.axes:
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _adorn_subplots(self)
#     466                 ncols=ncols,
#     467                 sharex=self.sharex,
# --> 468                 sharey=self.sharey,
#     469             )
#     470
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py in _handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     296                 layout = np.zeros((nrows + 1, ncols + 1), dtype=np.bool)
#     297                 for ax in axarr:
# --> 298                     layout[ax.rowNum, ax.colNum] = ax.get_visible()
#     299
#     300                 for ax in axarr:
#
# AttributeError: 'AxesSubplot' object has no attribute 'rowNum'

# %%
quant= df.select_dtypes(include=np.number).columns
quant
# Out:
# Index(['age', 'pression', 'cholester', 'taux_max', 'depression', 'pic'], dtype='object')

# %%
#Representation graphique de toutes les variables quantitative
plt.figure(figsize=[17,10])
plt.gcf().subplots_adjust(hspace = 0.5)
i=1
for quan in quant:
    plt.subplot(3,3,i)
    x=data[quan].hist()
    plt.title(quan)
    i+=1
